# %%
from class_assignment import SubfieldsInAI

# %%
SubfieldsInAI.Subfeilds()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
from class_assignment import OddEven

# %%
output = OddEven.oddEven()
print(output)

# %%
from class_assignment import ElegiblityForMarriage

# %%
findEligible = ElegiblityForMarriage.Elegible()
print(findEligible)
# Out:
# Your Gender:  Male
# Your Age: 25
# ELIGIBLE

# %%
from class_assignment import FindPercent

# %%
total, percentage = FindPercent.percentage()
print("Total=" + str(total))
print("Percentage=" + str(percentage))
# Out:
# Subject1= 25
# Subject2= 25
# Subject3= 25
# Subject4= 25
# Subject5= 25
# Total=125
# Percentage=25.0

# %%
from class_assignment import Triangle

# %%
Triangle.triangle()
# Out:
# Height: 25
# Breadth: 25
# Area formula: (Height*Breadth)/2
# Area of Triangle:312.5
# Height1= 36
# Height2= 36
# Breadth= 36
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle:108
