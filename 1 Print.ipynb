# %%
print("Welcome")
# Out:
# Welcome

# %%
print("this is my first program")
# Out:
# this is my first program

# %%
print()

# %%
print("this is sample text \nthis is second line")
# Out:
# this is sample text
# this is second line
