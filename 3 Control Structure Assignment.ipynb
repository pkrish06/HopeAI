# %%
print ("Welcome to Assignment-1")
# Out:
# Welcome to Assignment-1

# %%
Num1 = int(input("Enter the Num1:"))
Num2 = int(input("Enter the Num2:"))
Add  = Num1 + Num2
# Out:
# Enter the Num1: 25
# Enter the Num2: 35

# %%
print("Num1= " +  str(Num1))
print("Num2= " +  str(Num2))
print("Add= " +  str(Add))
# Out:
# Num1= 25
# Num2= 35
# Add= 60

# %%
#Body Mass Index

# %%
BMI = float(input("Enter the BMI value"))
if (BMI<18.5):
    print("Underweight")
elif (BMI<25):
    print("Normal")
elif (BMI<30):
    print("Overweight")
else:
    print("Obese")
# Out:
# Enter the BMI value 18.5
# Normal
