# %%
#deploy the saved model
import pickle

# %%
load_model=pickle.load(open("Multiple_Linear_Model_final.sav",'rb')) #load the already existing saved model

# %%
rd_input=float(input("R&D:"))
admin_input=float(input("Admin"))
mark_input=float(input("Marketing "))
fol_input=int(input("State_flo 0 or 1:"))
new_input=int(input("State_new 0 or 1:"))
# Out:
# R&D: 153441.51
# Admin 101145.55
# Marketing  407934.54
# State_flo 0 or 1: 0
# State_new 0 or 1: 0

# %%
result=load_model.predict([[rd_input,admin_input,mark_input,fol_input,new_input]])
result
# Out:
# C:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[180403.3085977]])
