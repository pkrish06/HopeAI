# %%
#deploy the saved model
import pickle

# %%
load_model=pickle.load(open("RF_Grid_Without_Testing_Training_Deployment_Model.sav",'rb')) #load the already existing saved model

# %%
age = int(input("age"))
sex_male = int(input("sex_male 0 or 1"))
bmi = float(input("bmi"))
children = int(input("children"))
smoker_yes = int(input("smoker_yes 0 or 1"))
# Out:
# age 32
# sex_male 0 or 1 0
# bmi 42
# children 0
# smoker_yes 0 or 1 1

# %%
result=load_model.predict([[age,sex_male,bmi,children,smoker_yes]])
result
# Out:
# C:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([44790.9525816])
