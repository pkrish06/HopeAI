# %%
#deploy the saved model
import pickle

# %%
load_StandardSclar = pickle.load(open("standard_scaler_Logistic_Grid.sav",'rb')) #load the already existing saved model
load_model=pickle.load(open("Logistic-Grid-Classification_Deployment_Model.sav",'rb')) #load the already existing saved model

# %%
age                =   30
bp                 =   60
al                 =   0
su                 =   0
bgr                =   138
bu                 =   15
sc                 =   1.1
sod                =   135
pot                =   4.4
hrmo               =   12.5181556196
pcv                =   38.868902439
wc                 =   8408.1911262799
rc                 =   4.7055970149
sg_b               =   0
sg_c               =   0
sg_d               =   0
sg_e               =   0
rbc_normal         =   1
pc_normal          =   1
pcc_present        =   0
ba_present         =   0
htn_yes            =   0
dm_yes             =   0
cad_yes            =   0
appet_yes          =   1
pe_yes             =   0
ane_yes            =   0
#classification_yes =  0

# %%
preprocessed_Input = load_StandardSclar.transform([[age,bp,al,su,bgr,bu,sc,sod,pot,hrmo,pcv,wc,rc,sg_b,sg_c,sg_d,sg_e,rbc_normal,pc_normal,pcc_present,ba_present,htn_yes,dm_yes,cad_yes,appet_yes,pe_yes,ane_yes]])
print(preprocessed_Input)
result=load_model.predict(preprocessed_Input)
print(result)
# Out:
# [[-1.35078903 -1.27764223 -0.68384276 -0.36409637 -0.15213862 -0.85572811
#   -0.35414204 -0.24429034 -0.07901381  0.01643586 -0.01610035  0.03813559
#    0.03721126 -0.49294082 -0.5454915  -0.45124263 -0.13840913  0.38924947
#    0.51055216 -0.34299717 -0.23570226 -0.73926425 -0.73926425 -0.29277002
#    0.51639778 -0.52223297 -0.44519456]]
# [0]
# C:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
age                =   21
bp                 =   70
al                 =   0
su                 =   0
bgr                =   148.1126760563
bu                 =   57.4821052632
sc                 =   3.0773560209
sod                =   137.5287539936
pot                =   4.6272435897
hrmo               =   12.5181556196
pcv                =   38.868902439
wc                 =   8408.1911262799
rc                 =   4.7055970149
sg_b               =   0
sg_c               =   1
sg_d               =   0
sg_e               =   0
rbc_normal         =   1
pc_normal          =   1
pcc_present        =   0
ba_present         =   0
htn_yes            =   0
dm_yes             =   0
cad_yes            =   0
appet_yes          =   0
pe_yes             =   0
ane_yes            =   1
#classification_yes =  1

# %%
preprocessed_Input = load_StandardSclar.transform([[age,bp,al,su,bgr,bu,sc,sod,pot,hrmo,pcv,wc,rc,sg_b,sg_c,sg_d,sg_e,rbc_normal,pc_normal,pcc_present,ba_present,htn_yes,dm_yes,cad_yes,appet_yes,pe_yes,ane_yes]])
print(preprocessed_Input)
result=load_model.predict(preprocessed_Input)
print(result)
# Out:
# [[-1.90207004 -0.50842064 -0.68384276 -0.36409637 -0.01958333 -0.05023019
#   -0.02111955 -0.00417361  0.02310393  0.01643586 -0.01610035  0.03813559
#    0.03721126 -0.49294082  1.83320914 -0.45124263 -0.13840913  0.38924947
#    0.51055216 -0.34299717 -0.23570226 -0.73926425 -0.73926425 -0.29277002
#   -1.93649167 -0.52223297  2.24620893]]
# [1]
# C:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
