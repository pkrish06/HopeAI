# %%
Num1 = 10
Num2 = 20
Add = Num1 + Num2
print(Add)
# Out:
# 30

# %%
print("The addition of two numbers")
Num1= 10
Num2=30
Add=Num1+Num2
print("The Number1 :", Num1)
print("The Number2 :", Num2)
print("The answer :", Add)
# Out:
# The addition of two numbers
# The Number1 : 10
# The Number2 : 30
# The answer : 40

# %%
Num1= int(input("Enter the Number 1"))
Num2= int(input("Enter the Number 2"))

# %%
print("The Sum of tow number is :", Num1+Num2)
print("The product of tow number is :", Num1*Num2)
# Out:
# The Sum of tow number is : ...
# The product of tow number is : ...
